# %%
import pandas as pd

# %%
data = {
    'Name':['Pavan','Kapil','Lalit','Ishan','Om','Ayush'],
    'Age':[23,None,44,42,None,24],
    'Salary':[30000,32333,3323,None,None,47647]

}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age   Salary
# 0  Pavan  23.0  30000.0
# 1  Kapil   NaN  32333.0
# 2  Lalit  44.0   3323.0
# 3  Ishan  42.0      NaN
# 4     Om   NaN      NaN
# 5  Ayush  24.0  47647.0

# %%
print(df.isnull().sum())
# Out:
# Name      0
# Age       2
# Salary    2
# dtype: int64
